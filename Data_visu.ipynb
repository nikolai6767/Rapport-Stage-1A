# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

data = """
function,calls,total,min,max,average
PRINT_EVENT,12067968,1.79498e+10,950,1.68418e+06,1487.39
PRINT_EVENT_PRINT_TIMESTAMP,12067968,7.60938e+09,430,1.64775e+06,630.543
PRINT_EVENT_GET_NAME,12067968,2.2252e+09,120,194575,184.389
PRINT_EVENT_GET_EVENT_STRING,12067968,5.94738e+09,110,1.68338e+06,492.823
PRINT_EVENT_GET_PRINT_EV_ATT,12067968,1.0606e+09,80,145274,87.8854
PRINT_EV_ATT,12067968,3.11077e+08,20,87372,25.7771
PRINT_EVENT_N,12067968,4.9126e+08,30,156484,40.7078
"""
df = pd.read_csv(io.StringIO(data))

fig, ax1 = plt.subplots(figsize=(14, 6))
bar_width = 0.25
index = range(len(df))

ax1.bar([i - bar_width for i in index], df["min"], width=bar_width, label="min (ns)", color='blue')
ax1.bar(index, df["average"], width=bar_width, label="average (ns)", color='orange')
ax1.bar([i + bar_width for i in index], df["max"], width=bar_width, label="max (ns)", color='red')

ax1.set_ylabel("Temps (ns)")
ax1.set_yscale('log')
ax1.set_xticks(index)
ax1.set_xticklabels(df["function"], rotation=45, ha="right")
ax1.grid(True, axis='y', linestyle='--', alpha=0.5)
ax1.legend(loc="upper left")

# ax2 = ax1.twinx()
# ax2.plot(index, df["calls"], color='green', marker='o', label="calls")
# ax2.set_ylabel("Nombre d'appels")
# ax2.legend(loc="upper right")
# ax2.set_yscale('log')


plt.title("Statistiques de PRINT_EVENT avec \\n")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

data = """
function,calls,total,min,max,average
PRINT_EVENT,12067968,2.39727e+10,1460,2.42825e+06,1986.47
PRINT_EVENT_PRINT_TIMESTAMP,12067968,7.92073e+09,460,356429,656.343
PRINT_EVENT_GET_NAME,12067968,2.25446e+09,130,109983,186.813
PRINT_EVENT_GET_EVENT_STRING,12067968,5.99492e+09,110,2.42676e+06,496.763
PRINT_EVENT_GET_PRINT_EV_ATT,12067968,1.06044e+09,80,208275,87.8725
PRINT_EV_ATT,12067968,3.11328e+08,20,208085,25.7979
PRINT_EVENT_ENDL,12067968,6.12696e+09,470,195345,507.705
"""

df = pd.read_csv(io.StringIO(data))

fig, ax1 = plt.subplots(figsize=(14, 6))
bar_width = 0.25
index = range(len(df))

ax1.bar([i - bar_width for i in index], df["min"], width=bar_width, label="min (ns)", color='blue')
ax1.bar(index, df["average"], width=bar_width, label="average (ns)", color='orange')
ax1.bar([i + bar_width for i in index], df["max"], width=bar_width, label="max (ns)", color='red')

ax1.set_ylabel("Temps (ns)")
ax1.set_yscale('log')
ax1.set_xticks(index)
ax1.set_xticklabels(df["function"], rotation=45, ha="right")
ax1.grid(True, axis='y', linestyle='--', alpha=0.5)
ax1.legend(loc="upper left")

ax2 = ax1.twinx()
ax2.plot(index, df["calls"], color='green', marker='o', label="calls")
ax2.set_ylabel("Nombre d'appels")
ax2.legend(loc="upper right")
ax2.set_yscale('log')


plt.title("Statistiques de PRINT_EVENT avec std::endl")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

data = """
function,calls,total,min,max,average
PRINT_TRACE,1,5.64836e+10,5.64836e+10,5.64836e+10,5.64836e+10
PRINT_TRACE_GET_THREAD_LIST,1,2.17102e+07,2.17102e+07,2.17102e+07,2.17102e+07
GET_THREAD_LIST_GET_ARCHIVE,1,170,170,170,170
GET_THREAD_LIST_GET_THREAD,1,305378,305378,305378,305378
PRINT_TRACE_EMPLACE_BACK,64,1.5906e+06,4580,555974,24853.1
PRINT_TRACE_POLLCURTOKEN,16316054,1.73768e+09,80,215896,106.501
PRINT_TRACE_PRINT_EVENT,16316054,3.40351e+10,1550,2.47165e+06,2085.99
PRINT_TRACE_GET_EV_OCC,16316054,4.89146e+09,40,1.38288e+06,299.794
PRINT_TRACE_GET_NEXT_TOKEN,16316054,2.12558e+10,190,4.0355e+06,1302.76
GET_TOKEN_IN_CALL_STACK,81580206,2.68365e+09,20,870731,32.8958
ENTER_BLOCK,4248150,1.09624e+08,20,96302,25.8052
"""

df = pd.read_csv(io.StringIO(data))

fig, ax1 = plt.subplots(figsize=(14, 6))
bar_width = 0.25
index = range(len(df))

ax1.bar([i - bar_width for i in index], df["min"], width=bar_width, label="min (ns)", color='blue')
ax1.bar(index, df["average"], width=bar_width, label="average (ns)", color='orange')
ax1.bar([i + bar_width for i in index], df["max"], width=bar_width, label="max (ns)", color='red')

ax1.set_ylabel("Temps (ns)")
ax1.set_yscale('log')
ax1.set_xticks(index)
ax1.set_xticklabels(df["function"], rotation=45, ha="right")
ax1.grid(True, axis='y', linestyle='--', alpha=0.5)
ax1.legend(loc="upper left")

ax2 = ax1.twinx()
ax2.plot(index, df["calls"], color='green', marker='o', label="calls")
ax2.set_ylabel("Nombre d'appels")
ax2.legend(loc="upper right")
ax2.set_yscale('log')


plt.title("Statistiques de PRINT_TRACE")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

data = """
function,calls,total,min,max,average
PRINT_TIMESTAMP,12067968,7.17329e+09,400,162544,594.408
PRINT_EVENT,12067968,2.41264e+10,1480,1.0197e+06,1999.21
OPEN_TRACE,1,2.75383e+06,2.75383e+06,2.75383e+06,2.75383e+06
PRINT_TRACE,1,5.68635e+10,5.68635e+10,5.68635e+10,5.68635e+10
PALLAS_PRINT,1,5.68804e+10,5.68804e+10,5.68804e+10,5.68804e+10
"""

df = pd.read_csv(io.StringIO(data))

fig, ax1 = plt.subplots(figsize=(14, 6))
bar_width = 0.25
index = range(len(df))

ax1.bar([i - bar_width for i in index], df["min"], width=bar_width, label="min (ns)", color='blue')
ax1.bar(index, df["average"], width=bar_width, label="average (ns)", color='orange')
ax1.bar([i + bar_width for i in index], df["max"], width=bar_width, label="max (ns)", color='red')

ax1.set_ylabel("Temps (ns)")
ax1.set_yscale('log')
ax1.set_xticks(index)
ax1.set_xticklabels(df["function"], rotation=45, ha="right")
ax1.grid(True, axis='y', linestyle='--', alpha=0.5)
ax1.legend(loc="upper left")

ax2 = ax1.twinx()
ax2.plot(index, df["calls"], color='green', marker='o', label="calls")
ax2.set_ylabel("Nombre d'appels")
ax2.legend(loc="upper right")
ax2.set_yscale('log')

plt.title("Statistiques générales de pallas_print")
plt.tight_layout()
plt.show()
